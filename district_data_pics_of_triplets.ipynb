# %% [markdown]
# README: https://www.dropbox.com/sh/n5w7fsvqepu5jis/AACLeWZmFTWOei1PGPUgZpSFa?dl=0&preview=Codebook+and+Data+Guide.pdf
#
# Supplement: https://gking.harvard.edu/files/gking/files/compact_supplement.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import pandas as pd
import fit_model_class
import ranking_class
import importlib
import preference_utils
from scipy import stats

# %% [markdown]
# # Read in the data

# %%
importlib.reload(fit_model_class)
importlib.reload(preference_utils)
pairwise_data, their_ranking, districts_in_shiny_item_num_dict = preference_utils.get_df('all', 5, 0)
usable_features = ['points', 'var_xcoord', 'var_ycoord', 'varcoord_ratio', 'avgline', 'varline', 'boyce', 'lenwid', 'jagged', 'parts', 'hull', 'bbox', 'reock', 'polsby', 'schwartzberg', 'circle_area', 'circle_perim', 'hull_area', 'hull_perim', 'orig_area', 'district_perim', 'corners', 'xvar', 'yvar', 'cornervar_ratio', 'sym_x', 'sym_y']
# Out:
# their ranking [ 75  95  19  26  21  55  98 120  43 108  80  63 102  89  57  91   5 101
#   59   3 119 113  18  24 109  32  74  22  67  13  14  85  68  16   1  93
#   64  81  82   4  72 110  28  33  62  11  27  17  96  29  36  23  65  87
#  112  35  45  41   8  30 117  15  84  39  77  61  86  51  71  66  50 106
#  105 107  34  46   9  56  52 104  37  53  25 111   6 121 114  99  60  20
#   58 100  70  79  73  97  54  49 115   2 103  31 116  48  83   0  69  47
#   40  42  38  88  10  76 118  92  44  78   7  12  90  94]

# %%
# SST
results, triplets = pairwise_data.st_violations(1, plot = True)
# Out:
# 5 108 55
# Pij, Pjk, Pik: 1.0 0.6666666666666666 0.875
# Num comparisons 6.0 6.0 8.0
# ^ STRONG TRANSITIVITY VIOLATION
# 9 52 39
# Pij, Pjk, Pik: 0.875 0.625 0.75
# Num comparisons 8.0 8.0 8.0
# ^ STRONG TRANSITIVITY VIOLATION
# 9 52 71
# Pij, Pjk, Pik: 0.875 0.625 0.625
# Num comparisons 8.0 8.0 8.0
# ^ STRONG TRANSITIVITY VIOLATION
# 17 59 113
# Pij, Pjk, Pik: 0.6 0.9 0.7
# Num comparisons 10.0 10.0 10.0
# ^ STRONG TRANSITIVITY VIOLATION
# 17 82 59
# Pij, Pjk, Pik: 0.6 0.7 0.6
# Num comparisons 10.0 10.0 10.0
# ^ STRONG TRANSITIVITY VIOLATION
# 17 82 113
# Pij, Pjk, Pik: 0.6 0.6 0.7
# Num comparisons 10.0 10.0 10.0
# 34 99 121
# Pij, Pjk, Pik: 0.6666666666666666 0.75 0.8333333333333334
# Num comparisons 12.0 12.0 12.0
# 37 66 84
# Pij, Pjk, Pik: 0.75 0.875 1.0
# Num comparisons 8.0 8.0 8.0
# 37 66 107
# Pij, Pjk, Pik: 0.75 0.625 0.875
# Num comparisons 8.0 8.0 8.0
# 37 107 84
# Pij, Pjk, Pik: 0.875 0.625 1.0
# Num comparisons 8.0 8.0 8.0
# 42 79 111
# Pij, Pjk, Pik: 1.0 0.8333333333333334 1.0
# Num comparisons 8.0 12.0 8.0
# 42 116 79
# Pij, Pjk, Pik: 0.625 0.9166666666666666 1.0
# Num comparisons 8.0 12.0 8.0
# 42 116 111
# Pij, Pjk, Pik: 0.625 1.0 1.0
# Num comparisons 8.0 12.0 8.0
# 56 23 112
# Pij, Pjk, Pik: 0.7873563218390804 0.6666666666666666 0.764367816091954
# Num comparisons 174.0 174.0 174.0
# ^ STRONG TRANSITIVITY VIOLATION
# 56 81 23
# Pij, Pjk, Pik: 0.632183908045977 0.5689655172413793 0.7873563218390804
# Num comparisons 174.0 174.0 174.0
# 56 81 112
# Pij, Pjk, Pik: 0.632183908045977 0.5459770114942529 0.764367816091954
# Num comparisons 174.0 174.0 174.0
# 57 5 55
# Pij, Pjk, Pik: 0.75 0.875 0.7
# Num comparisons 8.0 8.0 10.0
# ^ STRONG TRANSITIVITY VIOLATION
# ^ MODERATE TRANSITIVITY VIOLATION
# 57 5 108
# Pij, Pjk, Pik: 0.75 1.0 1.0
# Num comparisons 8.0 6.0 6.0
# 57 108 55
# Pij, Pjk, Pik: 1.0 0.6666666666666666 0.7
# Num comparisons 6.0 6.0 10.0
# ^ STRONG TRANSITIVITY VIOLATION
# 58 27 15
# Pij, Pjk, Pik: 0.85 0.5789473684210527 0.9210526315789473
# Num comparisons 40.0 38.0 38.0
# 58 96 15
# Pij, Pjk, Pik: 0.925 0.5789473684210527 0.9210526315789473
# Num comparisons 40.0 38.0 38.0
# ^ STRONG TRANSITIVITY VIOLATION
# 58 96 27
# Pij, Pjk, Pik: 0.925 0.675 0.85
# Num comparisons 40.0 40.0 40.0
# ^ STRONG TRANSITIVITY VIOLATION
# 60 34 99
# Pij, Pjk, Pik: 0.6666666666666666 0.6666666666666666 0.9166666666666666
# Num comparisons 12.0 12.0 12.0
# 60 34 121
# Pij, Pjk, Pik: 0.6666666666666666 0.8333333333333334 1.0
# Num comparisons 12.0 12.0 12.0
# 60 99 121
# Pij, Pjk, Pik: 0.9166666666666666 0.75 1.0
# Num comparisons 12.0 12.0 12.0
# 64 63 43
# Pij, Pjk, Pik: 0.8 0.8 1.0
# Num comparisons 10.0 10.0 10.0
# 64 72 43
# Pij, Pjk, Pik: 0.6 1.0 1.0
# Num comparisons 10.0 10.0 10.0
# 64 72 63
# Pij, Pjk, Pik: 0.6 0.9 0.8
# Num comparisons 10.0 10.0 10.0
# ^ STRONG TRANSITIVITY VIOLATION
# 66 107 84
# Pij, Pjk, Pik: 0.625 0.625 0.875
# Num comparisons 8.0 8.0 8.0
# 69 2 0
# Pij, Pjk, Pik: 0.8809523809523809 0.5079365079365079 0.8611111111111112
# Num comparisons 126.0 126.0 144.0
# ^ STRONG TRANSITIVITY VIOLATION
# 69 73 0
# Pij, Pjk, Pik: 0.8819444444444444 0.7293233082706767 0.8611111111111112
# Num comparisons 144.0 266.0 144.0
# ^ STRONG TRANSITIVITY VIOLATION
# 69 73 2
# Pij, Pjk, Pik: 0.8819444444444444 0.6428571428571429 0.8809523809523809
# Num comparisons 144.0 126.0 126.0
# ^ STRONG TRANSITIVITY VIOLATION
# 69 78 0
# Pij, Pjk, Pik: 0.7777777777777778 0.8214285714285714 0.8611111111111112
# Num comparisons 18.0 140.0 144.0
# 69 78 73
# Pij, Pjk, Pik: 0.7777777777777778 0.7714285714285715 0.8819444444444444
# Num comparisons 18.0 140.0 144.0
# 72 26 18
# Pij, Pjk, Pik: 0.8333333333333334 0.8333333333333334 0.9166666666666666
# Num comparisons 12.0 12.0 12.0
# 72 63 43
# Pij, Pjk, Pik: 0.9 0.8 1.0
# Num comparisons 10.0 10.0 10.0
# 72 89 18
# Pij, Pjk, Pik: 0.8333333333333334 0.9166666666666666 0.9166666666666666
# Num comparisons 12.0 12.0 12.0
# 72 89 26
# Pij, Pjk, Pik: 0.8333333333333334 0.75 0.8333333333333334
# Num comparisons 12.0 12.0 12.0
# 73 2 0
# Pij, Pjk, Pik: 0.6428571428571429 0.5079365079365079 0.7293233082706767
# Num comparisons 126.0 126.0 266.0
# 73 40 0
# Pij, Pjk, Pik: 0.5573770491803278 0.6065573770491803 0.7293233082706767
# Num comparisons 122.0 122.0 266.0
# 78 40 0
# Pij, Pjk, Pik: 0.7786885245901639 0.6065573770491803 0.8214285714285714
# Num comparisons 122.0 122.0 140.0
# 78 73 0
# Pij, Pjk, Pik: 0.7714285714285715 0.7293233082706767 0.8214285714285714
# Num comparisons 140.0 266.0 140.0
# 78 73 40
# Pij, Pjk, Pik: 0.7714285714285715 0.5573770491803278 0.7786885245901639
# Num comparisons 140.0 122.0 122.0
# 81 23 112
# Pij, Pjk, Pik: 0.5689655172413793 0.6666666666666666 0.5459770114942529
# Num comparisons 174.0 174.0 174.0
# ^ STRONG TRANSITIVITY VIOLATION
# ^ MODERATE TRANSITIVITY VIOLATION
# 82 59 113
# Pij, Pjk, Pik: 0.7 0.9 0.6
# Num comparisons 10.0 10.0 10.0
# ^ STRONG TRANSITIVITY VIOLATION
# ^ MODERATE TRANSITIVITY VIOLATION
# 89 26 18
# Pij, Pjk, Pik: 0.75 0.8333333333333334 0.9166666666666666
# Num comparisons 12.0 12.0 12.0
# 96 27 15
# Pij, Pjk, Pik: 0.675 0.5789473684210527 0.5789473684210527
# Num comparisons 40.0 38.0 38.0
# ^ STRONG TRANSITIVITY VIOLATION
# 116 79 111
# Pij, Pjk, Pik: 0.9166666666666666 0.8333333333333334 1.0
# Num comparisons 12.0 12.0 12.0
# Weak ST violations 0
# Strong ST violations 17
# Moderate ST violations 3
# out of 48 valid triplets that could have been violated.

# %%
d, n = pairwise_data.preference_matrix.shape

for i in range(n):
    for j in range(i+1, n):
        if pairwise_data.num_compared_matrix[i,j] > 0:
            if pairwise_data.preference_matrix[i,j] < .5:
                winner = j
                loser = i
            elif pairwise_data.preference_matrix[i,j] > .5:
                winner = i
                loser = j
            else:
                print('For', i,j, 'the empirical probability is 50%, so skipping this pair')
                continue
                
            print('Pij', pairwise_data.preference_matrix[winner, loser])
            print('num comparisons', pairwise_data.num_compared_matrix[winner, loser])
            pairwise_data.plot_pair_districts(winner, loser)
# Out:
# Pij 0.5079365079365079
# num comparisons 126.0
# Pij 0.6065573770491803
# num comparisons 122.0
# Pij 0.8611111111111112
# num comparisons 144.0
# Pij 0.7293233082706767
# num comparisons 266.0
# Pij 0.8214285714285714
# num comparisons 140.0
# Pij 0.5666666666666667
# num comparisons 90.0
# Pij 0.8809523809523809
# num comparisons 126.0
# Pij 0.6428571428571429
# num comparisons 126.0
# Pij 0.875
# num comparisons 8.0
# Pij 0.75
# num comparisons 8.0
# Pij 1.0
# num comparisons 6.0
# Pij 0.5777777777777777
# num comparisons 90.0
# Pij 0.6888888888888889
# num comparisons 90.0
# Pij 0.5888888888888889
# num comparisons 90.0
# Pij 0.7111111111111111
# num comparisons 90.0
# Pij 0.75
# num comparisons 8.0
# Pij 0.875
# num comparisons 8.0
# Pij 0.625
# num comparisons 8.0
# For 13 118 the empirical probability is 50%, so skipping this pair
# Pij 0.5789473684210527
# num comparisons 38.0
# Pij 0.9210526315789473
# num comparisons 38.0
# Pij 0.5789473684210527
# num comparisons 38.0
# Pij 0.6
# num comparisons 10.0
# Pij 0.6
# num comparisons 10.0
# Pij 0.7
# num comparisons 10.0
# Pij 0.8333333333333334
# num comparisons 12.0
# Pij 0.9166666666666666
# num comparisons 12.0
# Pij 0.9166666666666666
# num comparisons 12.0
# Pij 0.8333333333333334
# num comparisons 6.0
# Pij 0.6333333333333333
# num comparisons 90.0
# Pij 1.0
# num comparisons 6.0
# Pij 0.7873563218390804
# num comparisons 174.0
# Pij 0.5689655172413793
# num comparisons 174.0
# Pij 0.6666666666666666
# num comparisons 174.0
# Pij 0.5444444444444444
# num comparisons 90.0
# Pij 0.8333333333333334
# num comparisons 12.0
# Pij 0.75
# num comparisons 12.0
# Pij 0.85
# num comparisons 40.0
# Pij 0.675
# num comparisons 40.0
# Pij 0.6333333333333333
# num comparisons 90.0
# Pij 0.5444444444444444
# num comparisons 90.0
# Pij 0.5111111111111111
# num comparisons 90.0
# For 31 93 the empirical probability is 50%, so skipping this pair
# Pij 0.6666666666666666
# num comparisons 12.0
# Pij 0.6666666666666666
# num comparisons 12.0
# Pij 0.8333333333333334
# num comparisons 12.0
# Pij 0.75
# num comparisons 8.0
# Pij 1.0
# num comparisons 8.0
# Pij 0.875
# num comparisons 8.0
# Pij 0.625
# num comparisons 8.0
# For 39 71 the empirical probability is 50%, so skipping this pair
# Pij 0.5573770491803278
# num comparisons 122.0
# Pij 0.7786885245901639
# num comparisons 122.0
# Pij 1.0
# num comparisons 8.0
# Pij 1.0
# num comparisons 8.0
# Pij 0.625
# num comparisons 8.0
# Pij 0.8
# num comparisons 10.0
# Pij 1.0
# num comparisons 10.0
# Pij 1.0
# num comparisons 10.0
# For 48 49 the empirical probability is 50%, so skipping this pair
# Pij 0.625
# num comparisons 8.0
# Pij 0.7
# num comparisons 10.0
# Pij 0.6666666666666666
# num comparisons 6.0
# Pij 0.632183908045977
# num comparisons 174.0
# Pij 0.764367816091954
# num comparisons 174.0
# Pij 1.0
# num comparisons 6.0
# Pij 0.925
# num comparisons 40.0
# Pij 0.7
# num comparisons 10.0
# Pij 0.9
# num comparisons 10.0
# Pij 0.9166666666666666
# num comparisons 12.0
# Pij 1.0
# num comparisons 12.0
# Pij 0.8222222222222222
# num comparisons 90.0
# Pij 0.8
# num comparisons 10.0
# Pij 0.9
# num comparisons 10.0
# Pij 0.6
# num comparisons 10.0
# Pij 0.875
# num comparisons 8.0
# Pij 0.625
# num comparisons 8.0
# Pij 0.8333333333333334
# num comparisons 90.0
# Pij 0.8819444444444444
# num comparisons 144.0
# Pij 0.7777777777777778
# num comparisons 18.0
# Pij 0.8333333333333334
# num comparisons 12.0
# Pij 0.7714285714285715
# num comparisons 140.0
# Pij 0.6777777777777778
# num comparisons 90.0
# Pij 0.8333333333333334
# num comparisons 12.0
# Pij 0.9166666666666666
# num comparisons 12.0
# Pij 0.5459770114942529
# num comparisons 174.0
# Pij 0.6
# num comparisons 10.0
# Pij 0.625
# num comparisons 8.0
# Pij 0.5888888888888889
# num comparisons 90.0
# Pij 0.5888888888888889
# num comparisons 90.0
# Pij 0.8444444444444444
# num comparisons 90.0
# Pij 0.7
# num comparisons 90.0
# Pij 0.75
# num comparisons 12.0
# Pij 1.0
# num comparisons 12.0
